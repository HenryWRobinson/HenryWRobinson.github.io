# %% [markdown]
# <a href="https://colab.research.google.com/github/HenryWRobinson/HenryWRobinson.github.io/blob/main/Week5/coinapilooping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import os
from google.colab import files
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
URL = "https://rest.coinapi.io/v1/ohlcv/BTC/GBP/history?period_id=8HRS&time_start=2021-11-01T00:00:00&limit=100&include_empty_items=false&apikey=46F2E84A-2ACE-4C01-9FE1-BD1AC1451947"
response = requests.get("https://rest.coinapi.io/v1/ohlcv/BTC/GBP/history?period_id=8HRS&time_start=2021-11-01T00:00:00&limit=100&include_empty_items=false&apikey=46F2E84A-2ACE-4C01-9FE1-BD1AC1451947")
response
# Out:
# <Response [200]>

# %%
url_base = "https://rest.coinapi.io/v1/ohlcv/{}/GBP/history?period_id=8HRS&time_start=2021-11-01T00:00:00&limit=100&include_empty_items=false&apikey=46F2E84A-2ACE-4C01-9FE1-BD1AC1451947"
file_base = "CoinAPI{}.json"
coinseries = ['USD','BTC','ETH',"JPY"]
for i in coinseries:
  print(i)
  URL = url_base.format(i)
  print(URL)
  data = requests.get(URL).json()
  print(data)
  fileName = file_base.format(i)
  print(fileName)
  with open(fileName, 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)
  files.download('{}'.format(fileName))
# Out:
# USD
# https://rest.coinapi.io/v1/ohlcv/USD/GBP/history?period_id=8HRS&time_start=2021-11-01T00:00:00&limit=100&include_empty_items=false&apikey=46F2E84A-2ACE-4C01-9FE1-BD1AC1451947
# ...

# %%
response.json()
# Out:
# [{'price_close': 45560.27,
#   'price_high': 45689.97,
#   'price_low': 43397.32,
#   'price_open': 44868.52,
#   'time_close': '2021-11-01T07:59:46.0224390Z',
#   'time_open': '2021-11-01T00:00:01.2251820Z',
#   'time_period_end': '2021-11-01T08:00:00.0000000Z',
#   'time_period_start': '2021-11-01T00:00:00.0000000Z',
#   'trades_count': 13998,
#   'volume_traded': 393.847472177},
#  {'price_close': 45034.46,
#   'price_high': 45768.6,
#   'price_low': 44649.25,
#   'price_open': 45544.76,
#   'time_close': '2021-11-01T15:59:58.4635190Z',
#   'time_open': '2021-11-01T08:00:00.2379480Z',
#   'time_period_end': '2021-11-01T16:00:00.0000000Z',
#   'time_period_start': '2021-11-01T08:00:00.0000000Z',
#   'trades_count': 24637,
#   'volume_traded': 524.290265401},
#  {'price_close': 44352.57,
#   'price_high': 45055.51,
#   'price_low': 43937.02,
#   'price_open': 45023.86,
#   'time_close': '2021-11-01T23:59:59.1970000Z',
#   'time_open': '2021-11-01T16:00:00.2735900Z',
# ...
